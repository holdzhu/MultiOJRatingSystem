# %%
from rating_system import TopcoderRatingSystem
from user_manager import UserManager
from datetime import datetime
from utils import get_discretize_dict, get_codeforces_users_by_organization
from datetime import datetime

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['figure.figsize'] = (20, 10)

# %%
user_manager = UserManager()

# %%
user_manager.add_user(
    u'何柱', {
        'codeforces': 'Hezhu',
        'atcoder': 'Hezhu',
        'topcoder': 'Herzu',
    }
)
user_manager.add_user(
    u'陈鑫', {
        'codeforces': 'missever',
        'atcoder': 'missever',
        'topcoder': 'missever',
    }
)
user_manager.add_user(
    u'廖奇', {
        'codeforces': 'liao772002',
        'topcoder': 'liao772002',
    }
)
user_manager.add_user(
    u'杨宇同', {
        'codeforces': 'Orenji.Sora',
        'topcoder': 'Orenji.Sora',
    }
)
user_manager.add_user(
    u'徐浩', {
        'codeforces': 'femsub',
        'atcoder': 'femsub',
        'topcoder': 'femsub',
    }
)
user_manager.add_user(
    u'万笛文', {
        'codeforces': 'dnvtmf',
        'topcoder': 'dnvtmf',
    }
)
user_manager.add_user(
    u'潘星霖', {
        'codeforces': 'UESTC_Sphinx',
        'topcoder': 'UESTC_Sphinx',
    }
)
user_manager.add_user(
    u'沈柯', {
        'codeforces': 'xiper',
        'atcoder': 'xiper',
        'topcoder': 'xiper',
    }
)
# Out:
# loading rank from user Hezhu on codeforces
# loading rank from user Hezhu on atcoder
# loading rank from user Herzu on topcoder
# loading rank from user missever on codeforces
# loading rank from user missever on atcoder
# loading rank from user missever on topcoder
# loading rank from user liao772002 on codeforces
# loading rank from user liao772002 on topcoder
# loading rank from user Orenji.Sora on codeforces
# loading rank from user Orenji.Sora on topcoder
# failed to execute function from_user with argument ('Orenji.Sora',)
# loading rank from user femsub on codeforces
# loading rank from user femsub on atcoder
# loading rank from user femsub on topcoder
# loading rank from user dnvtmf on codeforces
# loading rank from user dnvtmf on topcoder
# loading rank from user UESTC_Sphinx on codeforces
# loading rank from user UESTC_Sphinx on topcoder
# failed to execute function from_user with argument ('UESTC_Sphinx',)
# loading rank from user xiper on codeforces
# loading rank from user xiper on atcoder
# loading rank from user xiper on topcoder

# %%
rating_system = TopcoderRatingSystem()
least_num_coders = 2
least_time=None # datetime(2016, 1, 1).timestamp()

# %%
user_manager.update_rating(rating_system, least_num_coders=least_num_coders, least_time=least_time, verbose=False)

# %%
time_dict = get_discretize_dict(list(user_manager.time_values))

# %%
for name, ratings in rating_system.rating_history.items():
    plt.plot([time_dict.get(item[1].time) for item in ratings], 
             [item[0] for item in ratings], 'o-', label=name)
plt.xlim((-1, len(time_dict)))
plt.xticks(range(len(time_dict))[::5])
ax = plt.legend(loc='center left', bbox_to_anchor=(1, 0.5)).axes
ax.set_xticklabels([datetime.fromtimestamp(x).date() for x in sorted(time_dict.keys())][::5])
for tick in ax.get_xticklabels():
    tick.set_rotation(45)

# %%
for name, ratings in rating_system.rating_history.items():
    plt.plot([datetime.fromtimestamp(item[1].time) for item in ratings], 
             [item[0] for item in ratings], 'o-', label=name)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
user_manager = UserManager()
codeforces_users = get_codeforces_users_by_organization(662)
for user in codeforces_users:
    user_manager.add_user(user, {'codeforces': user})
# Out:
# loading rank from user missever on codeforces
# loading rank from user James on codeforces
# loading rank from user Orenji.Sora on codeforces
# loading rank from user fwm94 on codeforces
# loading rank from user femsub on codeforces
# loading rank from user dnvtmf on codeforces
# loading rank from user qscqesze on codeforces
# loading rank from user UESTC_Sphinx on codeforces
# loading rank from user CS_LYJ1997 on codeforces
# loading rank from user luozongying on codeforces

# %%
for name, ratings in user_manager.user_ranks.items():
    plt.plot([datetime.fromtimestamp(item.raw_data['ratingUpdateTimeSeconds']) for item in ratings], 
             [item.raw_data['newRating'] for item in ratings], 'o-', label=name)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# plt.xlim((datetime(2017,1,1), datetime.today()))
